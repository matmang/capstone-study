# %%
import sys, os
sys.path.append(os.pardir)
import numpy as np
from dataset.mnist import load_mnist

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True, one_hot_label=True)

train_size = x_train.shape[0]
batch_size = 10
batch_mask = np.random.choice(train_size, batch_size)
x_batch = x_train[batch_mask]
t_batch = t_train[batch_mask]

def cross_entropy_error(y, t):
    if y.ndim == 1:
        t = t.reshape(1, t.size)
        y = y.reshape(1, y.size)
    
    batch_size = y.shape[0]
    return -np.sum(t * np.log(y)) / batch_size

# %%
def numerical_diff(f, x):
    h = 1e-4
    return (f(x+h) - f(x-h)) / (2*h)

def numerical_gradient(f, x):
    h = 1e-4
    grad = np.zeros_like(x)

    for idx in range(x.size):
        tmp_val = x[idx]
        x[idx] = tmp_val + h
        fxh1 = f(x)

        x[idx] = tmp_val - h
        fxh2 = f(x)

        grad[idx] = (fxh1 - fxh2) / (2 * h)
        x[idx] = tmp_val

    return grad

# %%
def gradient_descent(f, init_x, lr=0.01, step_num=100):
    x = init_x

    for i in range(step_num):
        grad = numerical_gradient(f, x)
        x -= lr * grad
    
    return x

# %%
def softmax(x):
    x = x - np.max(x, axis=-1, keepdims=True)   # オーバーフロー対策
    return np.exp(x) / np.sum(np.exp(x), axis=-1, keepdims=True)

def cross_entropy_error(y, t):
    if y.ndim == 1:
        t = t.reshape(1, t.size)
        y = y.reshape(1, y.size)
        
    if t.size == y.size:
        t = t.argmax(axis=1)
             
    batch_size = y.shape[0]
    return -np.sum(np.log(y[np.arange(batch_size), t] + 1e-7)) / batch_size

sys.path.append(os.pardir)
import numpy as np
from common.gradient import numerical_gradient

class simpleNet:
    def __init__(self):
        self.W = np.random.randn(2,3)

    def predict(self, x):
        return np.dot(x, self.W)

    def loss(self, x, t):
        z = self.predict
        y = softmax(z)
        loss = cross_entropy_error(y, t)

        return loss

# %%
from common.functions import *
from common.gradient import numerical_gradient

def sigmoid(x):
    return 1 / (1 + np.exp(-x))  

class TwoLayerNet:
    def __init__(self, input_size, hidden_size, output_size, weight_init_std=0.01):
        self.params = {}
        self.params['W1'] = weight_init_std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size)
        self.params['W2'] = weight_init_std * np.random.randn(hidden_size, output_size)
        self.params['b2'] = np.zeros(output_size)

    def predict(self, x):
        W1, W2 = self.params['W1'], self.params['W2']
        b1, b2 = self.params['b1'], self.params['b2']

        a1 = np.dot(x, W1) + b1
        z1 = sigmoid(a1)
        a2 = np.dot(z1, W2) + b2
        y = softmax(a2)

        return y
    
    def loss(self, x, t):
        y = self.predict(x)

        return cross_entropy_error(y, t)

    def accuracy(self, x, t):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        t = np.argmax(t, axis=1)

        accuracy = np.sum(y == t) / float(x.shape[0])
        return accuracy

    def numerical_gradient(self, x, t):
        loss_W = lambda W: self.loss(x, t)

        grads = {}
        grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
        grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
        grads['W2'] = numerical_gradient(loss_W, self.params['W2'])
        grads['b2'] = numerical_gradient(loss_W, self.params['b2'])

        return grads

# %%
train_loss_list = []
train_acc_list = []
test_acc_list = []

iters_num = 10000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

iter_per_epoch = max(train_size / batch_size, 1)

network = TwoLayerNet(input_size=784, hidden_size=50, output_size=10)

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grad = network.numerical_gradient(x_batch, t_batch)

    for key in ('W1', 'b1', 'W2', 'b2'):
        network.params[key] -= learning_rate * grad[key]

    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        print("train acc, test acc | " + str(train_acc) + ", " + str(test_acc))
# Out:
# train acc, test acc | 0.09035, 0.0892
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/xn/dxdr0gzs2bld2s01df0dtst00000gn/T/ipykernel_23168/2872011140.py in <module>
#      17     t_batch = t_train[batch_mask]
#      18
# ---> 19     grad = network.numerical_gradient(x_batch, t_batch)
#      20
#      21     for key in ('W1', 'b1', 'W2', 'b2'):
#
# /var/folders/xn/dxdr0gzs2bld2s01df0dtst00000gn/T/ipykernel_23168/414986507.py in numerical_gradient(self, x, t)
#      41
#      42         grads = {}
# ---> 43         grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
#      44         grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
#      45         grads['W2'] = numerical_gradient(loss_W, self.params['W2'])
#
# ~/Documents/GitHub/capstone-study/week3/../common/gradient.py in numerical_gradient(f, x)
#      44
#      45         x[idx] = tmp_val - h
# ---> 46         fxh2 = f(x) # f(x-h)
#      47         grad[idx] = (fxh1 - fxh2) / (2*h)
#      48
#
# /var/folders/xn/dxdr0gzs2bld2s01df0dtst00000gn/T/ipykernel_23168/414986507.py in <lambda>(W)
#      38
#      39     def numerical_gradient(self, x, t):
# ---> 40         loss_W = lambda W: self.loss(x, t)
#      41
#      42         grads = {}
#
# /var/folders/xn/dxdr0gzs2bld2s01df0dtst00000gn/T/ipykernel_23168/414986507.py in loss(self, x, t)
#      25
#      26     def loss(self, x, t):
# ---> 27         y = self.predict(x)
#      28
#      29         return cross_entropy_error(y, t)
#
# /var/folders/xn/dxdr0gzs2bld2s01df0dtst00000gn/T/ipykernel_23168/414986507.py in predict(self, x)
#      20         z1 = sigmoid(a1)
#      21         a2 = np.dot(z1, W2) + b2
# ---> 22         y = softmax(a2)
#      23
#      24         return y
#
# /var/folders/xn/dxdr0gzs2bld2s01df0dtst00000gn/T/ipykernel_23168/3036460218.py in softmax(x)
#       1 def softmax(x):
# ----> 2     x = x - np.max(x, axis=-1, keepdims=True)   # オーバーフロー対策
#       3     return np.exp(x) / np.sum(np.exp(x), axis=-1, keepdims=True)
#       4
#       5 def cross_entropy_error(y, t):
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2731     5
#    2732     """
# -> 2733     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2734                           keepdims=keepdims, initial=initial, where=where)
#    2735
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      68
#      69
# ---> 70 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#      71     passkwargs = {k: v for k, v in kwargs.items()
#      72                   if v is not np._NoValue}
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# _pydevd_bundle/pydevd_cython.pyx in _pydevd_bundle.pydevd_cython.ThreadTracer.__call__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_is_thread_alive.py in is_thread_alive(t)
#       7 if hasattr(_temp, '_is_stopped'):  # Python 3.x has this
#       8
# ----> 9     def is_thread_alive(t):
#      10         return not t._is_stopped
#      11
#
# KeyboardInterrupt:
